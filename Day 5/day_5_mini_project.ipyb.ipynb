# %%
import sqlite3
import pandas as pd
import warnings
import matplotlib.pyplot as plt
print("==== Packages Downloaded Successfully ====")
warnings.filterwarnings("ignore")
print("==== Warnings Ignored ====")
print("Pandas Installed :",pd.__version__)
print("Sqlite Installed :",sqlite3.version)
print("==== Packages Installed Successfully ====")
# Out:
# ==== Packages Downloaded Successfully ====
# ==== Warnings Ignored ====
# Pandas Installed : 2.2.2
# Sqlite Installed : 2.6.0
# ==== Packages Installed Successfully ====

# %%
data = pd.read_csv("/content/drive/MyDrive/Summer_Internship_2026/student_performance.csv")
print("=== Data Loaded Successfully ===")
# Out:
# === Data Loaded Successfully ===

# %%
print(data.shape[0],"Students",data.shape[1],"Columns")
# Out:
# 30 Students 13 Columns

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

# %%
data.to_sql(
    'internship',
    conn,
    if_exists='replace',
    index=False
)
# Out:
# 30

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

query = "SELECT * FROM internship"
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# ...

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

query = "SELECT student_id , name FROM internship LIMIT 5"
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#    student_id          name
# 0        1001  Aarav Sharma
# 1        1002   Priya Patel
# 2        1003   Rohit Verma
# 3        1004   Sneha Reddy
# 4        1005    Arjun Nair

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

query = "SELECT name , math_score FROM internship WHERE math_score > 80"
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#               name  math_score
# 0     Aarav Sharma          85
# 1       Arjun Nair          92
# 2      Divya Singh          88
# 3       Ananya Das          95
# 4       Suresh Rao          83
# 5     Ritu Agarwal          87
# 6   Swati Kulkarni          90
# 7      Tanvi Mehta          93
# 8        Amit Bose          86
# 9    Gaurav Shukla          84
# 10  Akanksha Yadav          91

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

query = "SELECT name , department  FROM internship WHERE department = 'Computer Science' "
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#               name        department
# 0     Aarav Sharma  Computer Science
# 1      Priya Patel  Computer Science
# 2       Arjun Nair  Computer Science
# 3      Divya Singh  Computer Science
# 4       Ananya Das  Computer Science
# 5       Suresh Rao  Computer Science
# 6      Ajay Tiwari  Computer Science
# 7   Swati Kulkarni  Computer Science
# 8     Nisha Kapoor  Computer Science
# 9      Tanvi Mehta  Computer Science
# 10       Amit Bose  Computer Science
# 11   Gaurav Shukla  Computer Science
# 12  Akanksha Yadav  Computer Science

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

query = "SELECT name , department , math_score FROM internship WHERE department = 'Computer Science' AND math_score > 80 ORDER BY math_score DESC LIMIT 5"
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#              name        department  math_score
# 0      Ananya Das  Computer Science          95
# 1     Tanvi Mehta  Computer Science          93
# 2      Arjun Nair  Computer Science          92
# 3  Akanksha Yadav  Computer Science          91
# 4  Swati Kulkarni  Computer Science          90

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()

query = "SELECT name , department  FROM internship WHERE department = 'Computer Science' "
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#               name        department
# 0     Aarav Sharma  Computer Science
# 1      Priya Patel  Computer Science
# 2       Arjun Nair  Computer Science
# 3      Divya Singh  Computer Science
# 4       Ananya Das  Computer Science
# 5       Suresh Rao  Computer Science
# 6      Ajay Tiwari  Computer Science
# 7   Swati Kulkarni  Computer Science
# 8     Nisha Kapoor  Computer Science
# 9      Tanvi Mehta  Computer Science
# 10       Amit Bose  Computer Science
# 11   Gaurav Shukla  Computer Science
# 12  Akanksha Yadav  Computer Science

# %%
def run_query(query, db_name='internship.db'):
  conn = sqlite3.connect(db_name)
  data = pd.read_sql(query, conn)
  conn.close()
  print(f"=== Data from {db_name} Loaded Successfully ===")
  print("")
  return data

# %%
query = "SELECT name , department  FROM internship WHERE department = 'Computer Science' "
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#               name        department
# 0     Aarav Sharma  Computer Science
# 1      Priya Patel  Computer Science
# 2       Arjun Nair  Computer Science
# 3      Divya Singh  Computer Science
# 4       Ananya Das  Computer Science
# 5       Suresh Rao  Computer Science
# 6      Ajay Tiwari  Computer Science
# 7   Swati Kulkarni  Computer Science
# 8     Nisha Kapoor  Computer Science
# 9      Tanvi Mehta  Computer Science
# 10       Amit Bose  Computer Science
# 11   Gaurav Shukla  Computer Science
# 12  Akanksha Yadav  Computer Science

# %%
query = "SELECT student_id , name FROM internship LIMIT 5"
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#    student_id          name
# 0        1001  Aarav Sharma
# 1        1002   Priya Patel
# 2        1003   Rohit Verma
# 3        1004   Sneha Reddy
# 4        1005    Arjun Nair

# %%
query = "SELECT name , department , math_score FROM internship WHERE math_score>=90 ORDER BY math_score DESC LIMIT 5"
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#              name        department  math_score
# 0      Ananya Das  Computer Science          95
# 1     Tanvi Mehta  Computer Science          93
# 2      Arjun Nair  Computer Science          92
# 3  Akanksha Yadav  Computer Science          91
# 4  Swati Kulkarni  Computer Science          90

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = "SELECT name , math_score , science_score , programming_score , attendance_percentage FROM internship WHERE department = 'Computer Science' "
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#               name  math_score  science_score  programming_score  \
# 0     Aarav Sharma          85             78                 91
# 1      Priya Patel          76             82                 79
# 2       Arjun Nair          92             88                 95
# 3      Divya Singh          88             91                 93
# 4       Ananya Das          95             89                 97
# 5       Suresh Rao          83             86                 88
# 6      Ajay Tiwari          71             69                 76
# 7   Swati Kulkarni          90             87                 92
# 8     Nisha Kapoor          79             84                 83
# 9      Tanvi Mehta          93             90                 96
# 10       Amit Bose          86             82                 89
# 11   Gaurav Shukla          84             79                 87
# 12  Akanksha Yadav          91             93                 94
#
# ...

# %%
query = "SELECT name , math_score , science_score , programming_score , attendance_percentage FROM internship WHERE department = 'Computer Science' ORDER BY programming_score DESC"
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#               name  math_score  science_score  programming_score  \
# 0       Ananya Das          95             89                 97
# 1      Tanvi Mehta          93             90                 96
# 2       Arjun Nair          92             88                 95
# 3   Akanksha Yadav          91             93                 94
# 4      Divya Singh          88             91                 93
# 5   Swati Kulkarni          90             87                 92
# 6     Aarav Sharma          85             78                 91
# 7        Amit Bose          86             82                 89
# 8       Suresh Rao          83             86                 88
# 9    Gaurav Shukla          84             79                 87
# 10    Nisha Kapoor          79             84                 83
# 11     Priya Patel          76             82                 79
# 12     Ajay Tiwari          71             69                 76
#
# ...

# %%
query = "SELECT name ,department , attendance_percentage FROM internship WHERE department != 'Civil' AND attendance_percentage > 90 ORDER BY attendance_percentage DESC"
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#              name        department  attendance_percentage
# 0      Ananya Das  Computer Science                     98
# 1     Tanvi Mehta  Computer Science                     97
# 2     Divya Singh  Computer Science                     96
# 3     Sneha Reddy        Mechanical                     95
# 4  Akanksha Yadav  Computer Science                     95
# 5  Swati Kulkarni  Computer Science                     94
# 6    Ritu Agarwal       Electronics                     93
# 7    Aarav Sharma  Computer Science                     92
# 8   Kavya Nambiar        Mechanical                     91
# 9       Amit Bose  Computer Science                     91

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = """
SELECT name ,department , attendance_percentage
FROM internship WHERE department != 'Civil' AND attendance_percentage > 90
ORDER BY attendance_percentage
DESC
"""
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#              name        department  attendance_percentage
# 0      Ananya Das  Computer Science                     98
# 1     Tanvi Mehta  Computer Science                     97
# 2     Divya Singh  Computer Science                     96
# 3     Sneha Reddy        Mechanical                     95
# 4  Akanksha Yadav  Computer Science                     95
# 5  Swati Kulkarni  Computer Science                     94
# 6    Ritu Agarwal       Electronics                     93
# 7    Aarav Sharma  Computer Science                     92
# 8   Kavya Nambiar        Mechanical                     91
# 9       Amit Bose  Computer Science                     91

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = """
SELECT name ,department , attendance_percentage
FROM internship WHERE department != 'Mechanical' AND attendance_percentage > 93
ORDER BY attendance_percentage
DESC
"""
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#              name        department  attendance_percentage
# 0      Ananya Das  Computer Science                     98
# 1     Tanvi Mehta  Computer Science                     97
# 2     Divya Singh  Computer Science                     96
# 3  Akanksha Yadav  Computer Science                     95
# 4  Swati Kulkarni  Computer Science                     94

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = """
SELECT DISTINCT name from internship
"""
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#               name
# 0     Aarav Sharma
# 1      Priya Patel
# 2      Rohit Verma
# 3      Sneha Reddy
# 4       Arjun Nair
# 5      Meera Joshi
# 6      Kiran Kumar
# 7      Divya Singh
# 8     Rahul Mishra
# 9       Ananya Das
# 10     Vikram Iyer
# 11     Pooja Gupta
# 12      Suresh Rao
# 13   Kavya Nambiar
# 14     Ajay Tiwari
# 15    Ritu Agarwal
# 16    Manoj Pandey
# 17  Swati Kulkarni
# 18  Deepak Chauhan
# 19    Nisha Kapoor
# 20   Harish Pillai
# 21     Tanvi Mehta
# 22    Sanjay Dubey
# 23   Preeti Saxena
# 24       Amit Bose
# 25      Rekha Nair
# 26   Gaurav Shukla
# 27   Sunita Pillai
# 28      Nitin Jain
# 29  Akanksha Yadav

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = """
SELECT name FROM internship WHERE name >= 'A' AND name < 'F' ORDER BY name;
"""
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#              name
# 0    Aarav Sharma
# 1     Ajay Tiwari
# 2  Akanksha Yadav
# 3       Amit Bose
# 4      Ananya Das
# 5      Arjun Nair
# 6  Deepak Chauhan
# 7     Divya Singh

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = """
SELECT department,
COUNT(*) AS student_count,
ROUND(AVG(math_score),2) AS avg_math_score,
ROUND(AVG(science_score),2) AS avg_science_score,
ROUND(AVG(programming_score),2) AS avg_programming_score
FROM internship
GROUP BY department
ORDER BY avg_math_score DESC;
"""
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#          department  student_count  avg_math_score  avg_science_score  \
# 0  Computer Science             13           85.62              84.46
# 1        Mechanical              6           71.00              76.50
# 2       Electronics              6           71.00              74.17
# 3             Civil              5           63.40              66.60
#
#    avg_programming_score
# 0                  89.23
# 1                  49.33
# 2                  61.50
# 3                  40.60

# %%
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
query = """
SELECT department , COUNT(*) AS student_count , AVG(math_score) AS avg_math_score
FROM internship
GROUP BY department
HAVING avg_math_score > 70
ORDER BY avg_math_score DESC;
"""
data = pd.read_sql(query,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#          department  student_count  avg_math_score
# 0  Computer Science             13       85.615385
# 1        Mechanical              6       71.000000
# 2       Electronics              6       71.000000

# %%
query = """
select
gender,
count(*) AS num_students,
ROUND(AVG(math_score), 2) AS avg_math,
ROUND(AVG(programming_score), 2) AS avg_programming,
ROUND(AVG(attendance_percentage), 2) AS avg_attendance
from internship
group by gender
"""
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#    gender  num_students  avg_math  avg_programming  avg_attendance
# 0  Female            15     78.47             70.2           88.53
# 1    Male            15     73.67             65.0           80.47

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT department , ROUND(AVG(math_score)) AS avg_math
FROM internship
GROUP BY department
ORDER BY avg_math DESC
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#          department  avg_math
# 0  Computer Science      86.0
# 1        Mechanical      71.0
# 2       Electronics      71.0
# 3             Civil      63.0

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.title("AVERAGE MATHS SCORE OF DEPARTMENTS")
plt.xlabel("DEPARTMENT")
plt.ylabel("AVERAGE MATHS SCORE")
plt.bar(data['department'],data['avg_math'] , color =['red','yellow','green','violet'])
plt.xticks(rotation=45)
# plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT department , AVG(attendance_percentage) AS avg_attendance
FROM internship
GROUP BY department
ORDER BY attendance_percentage DESC
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#          department  avg_attendance
# 0        Mechanical       83.500000
# 1  Computer Science       90.692308
# 2             Civil       74.600000
# 3       Electronics       80.333333

# %%
fig , ax = plt.subplots(figsize=(10,8))
plt.title("AVERAGE ATTENDANCE OF DEPARTMENTS")
plt.xlabel("DEPARTMENT")
plt.ylabel("AVERAGE ATTENDANCE")
bars = plt.bar(data['department'],data['avg_attendance'], color = ['orange','blue','yellow','red'])

# Add the percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', va='bottom') # +0.5 for a small offset above the bar

plt.show()

# %%
fig , ax = plt.subplots(figsize=(10,8))
plt.title("AVERAGE ATTENDANCE OF DEPARTMENTS")
plt.xlabel("DEPARTMENT")
plt.ylabel("AVERAGE ATTENDANCE")
bars = plt.bar(data['department'],data['avg_attendance'], color = ['orange','blue','yellow','red'])

# Add the percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', va='bottom') # +0.5 for a small offset above the bar

plt.show()

# %%
fig , ax = plt.subplots(figsize=(10,8))
plt.title("AVERAGE ATTENDANCE OF DEPARTMENTS")
plt.xlabel("AVERAGE ATTENDANCE")
plt.ylabel("DEPARTMENT")
bars = plt.barh(data['department'],data['avg_attendance'], color = ['orange','blue','yellow','red'])

# Add the percentage values on top of the bars
# for bar in bars:
#     xval = bar.get_width()
#     plt.text(xval + 0.5, bar.get_y() + bar.get_height()/2, round(xval, 2), ha='left', va='center') # +0.5 for a small offset to the right of the bar

plt.show()

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT gender , AVG(attendance_percentage) AS avg_attendance
FROM internship
GROUP BY gender
ORDER BY attendance_percentage DESC
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#    gender  avg_attendance
# 0    Male       80.466667
# 1  Female       88.533333

# %%
fig , ax = plt.subplots(figsize=(10,8))
plt.title("AVERAGE ATTENDANCE OF DEPARTMENTS")
plt.xlabel("GENDER")
plt.ylabel("AVERAGE ATTENDANCE")
plt.bar(data['gender'],data['avg_attendance'], color = ['red','yellow'])
plt.show()

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT name , (math_score + programming_score + math_score + science_score + english_score) AS total_score
FROM internship
ORDER BY total_score
LIMIT 8;
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#              name  total_score
# 0    Manoj Pandey          266
# 1    Sanjay Dubey          289
# 2   Sunita Pillai          292
# 3    Rahul Mishra          298
# 4     Meera Joshi          304
# 5     Rohit Verma          320
# 6     Kiran Kumar          320
# 7  Deepak Chauhan          320

# %%
fig , ax = plt.subplots(figsize=(10,8))
plt.title("TOP 8 STUDENTS WITH TOP SCORES IN ALL THE DEPARTMENT")
plt.xlabel("STUDENTS")
plt.ylabel("TOTAL SCORE")
plt.barh(data['name'],data['total_score'], color = ['red','black','pink','yellow','violet','blue','grey','gold'])
plt.show()

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the database and fetch the data for departments
conn = sqlite3.connect('internship.db')
query = "SELECT department FROM internship"
data_for_chart = pd.read_sql(query, conn)
conn.close()

# Count students department-wise
department_data = data_for_chart.groupby('department').size().reset_index(name='student_count')
dept_count = department_data.set_index('department')['student_count']

# Create pie chart

fig, ax = plt.subplots(figsize=(8,8))

plt.pie(
    dept_count.values,
    labels=dept_count.index,
    autopct='%1.1f%%',
    colors=['pink', 'lightblue', 'grey', 'yellow']
)

plt.title("STUDENT DISTRIBUTION BY DEPARTMENT")

plt.show()

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT gender , ROUND(AVG(programming_score)) AS avg_programming_score
FROM internship
WHERE gender = "Female"
GROUP BY gender
ORDER BY avg_programming_score DESC
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#    gender  avg_programming_score
# 0  Female                   70.0

# %%
fig , ax = plt.subplots(figsize=(2,7))
plt.title("AVERAGE PROGRAMMING SCORE OF FEMALE")
plt.xlabel("GENDER")
plt.ylabel("AVERAGE PROGRAMMING SCORE")
plt.bar(data['gender'],data['avg_programming_score'], color = ['gold'])
plt.show()

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT department , AVG(attendance_percentage) AS avg_attendance
FROM internship
GROUP BY department
HAVING avg_attendance > 85
ORDER BY avg_attendance DESC
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#          department  avg_attendance
# 0  Computer Science       90.692308

# %%
fig , ax = plt.subplots(figsize=(2,7))
plt.title("AVERAGE ATTENDANCE OF DEPARTMENT")
plt.xlabel("DEPARTMENT")
plt.ylabel("AVERAGE ATTENDANCE")
plt.bar(data['department'],data['avg_attendance'])
plt.show()

# %%
import matplotlib.pyplot as plt
conn = sqlite3.connect('internship.db')
cursor = conn.cursor()
chart_sql = """
SELECT department , ROUND(AVG(programming_score)) AS avg_program
FROM internship
GROUP BY department
ORDER BY avg_program DESC
"""
data = pd.read_sql(chart_sql,conn)
print("=== DataBase Connected Successfully ===")
print("")
print(data)
conn.close()
# Out:
# === DataBase Connected Successfully ===
#
#          department  avg_program
# 0  Computer Science         89.0
# 1       Electronics         62.0
# 2        Mechanical         49.0
# 3             Civil         41.0

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.title("AVERAGE PROGRAMMING SCORE OF DEPARTMENTS")
plt.xlabel("DEPARTMENT")
plt.ylabel("AVERAGE PROGRAMMING SCORE")
plt.bar(data['department'],data['avg_program'] , color =['red','yellow','green','violet'])
plt.xticks(rotation=45)
# plt.grid()
plt.show()

# %%
query = "SELECT student_id , name , programming_score FROM internship"
print(run_query(query))
# Out:
# === Data from internship.db Loaded Successfully ===
#
#     student_id            name  programming_score
# 0         1001    Aarav Sharma                 91
# 1         1002     Priya Patel                 79
# 2         1003     Rohit Verma                 55
# 3         1004     Sneha Reddy                 48
# 4         1005      Arjun Nair                 95
# 5         1006     Meera Joshi                 52
# 6         1007     Kiran Kumar                 40
# 7         1008     Divya Singh                 93
# 8         1009    Rahul Mishra                 45
# 9         1010      Ananya Das                 97
# 10        1011     Vikram Iyer                 72
# 11        1012     Pooja Gupta                 44
# 12        1013      Suresh Rao                 88
# 13        1014   Kavya Nambiar                 51
# 14        1015     Ajay Tiwari                 76
# 15        1016    Ritu Agarwal                 69
# 16        1017    Manoj Pandey                 38
# ...
